# %% [markdown]
# <a href="https://colab.research.google.com/github/VartanyanAdik/service_by_reviews/blob/main/django.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install django
# !pip install django djangorestframework
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.1 MB/s eta 0:00:00
# ...

# %%
# !django-admin startproject movie_review_classifier
# !cd movie_review_classifier && django-admin startapp reviews
# Out:
# CommandError: '/content/movie_review_classifier' already exists
